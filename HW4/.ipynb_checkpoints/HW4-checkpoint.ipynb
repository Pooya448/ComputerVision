# %% [markdown]
# # HomeWork 4
#
# **DeadLine : 12:00 PM 28 Mehr 1399**
#
# **Total points : 120pts**

# %% [markdown]
# Import some prerequisites

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# Run this cell for plotting

# %%
def plotter(img_list, r, w, gray, wr, hr, fig_name = None):
    '''
    Plots images' list with its' caption and saves result image if you want.

    Parameters:
        img_list (list): The list of tuples of image and its' caption.
        r (int): The number of row(s).
        w (int): The number of colunm(s).
        gray (bool): The flag for plotting images in grayscale mode.
        wr (int): The width of one figure.
        hr (int): The height of one figure.
        fig_name (str): The name of the image of the plot. if not set this parameter the plot doesn't save.
    '''
    
    plt.rcParams['figure.figsize'] = (wr, hr)
    for i in range(len(img_list)):
        plt.subplot(r, w, i + 1)
        if img_list[i][2] == 'img':
            if gray:
                plt.imshow(img_list[i][0], cmap = 'gray')
            else:
                plt.imshow(img_list[i][0])
            plt.xticks([])
            plt.yticks([])
        elif img_list[i][2] == 'hist':
            plt.bar(np.arange(len(img_list[i][0])), img_list[i][0], color = 'c')
        else:
            raise Exception("Only image or histogram. Use third parameter of tuples in img_list and set it to img or hist.")
        plt.title(img_list[i][1])
    if fig_name is not None:
        plt.savefig(fig_name + '.png')
    plt.show()

# %% [markdown]
# # PART 3
#
# **Point : 30 pts**

# %% [markdown]
# Here is for your helper functions(optional)

# %%
def compute_phase_magnitude(image):
    dft = np.fft.fft2(image)
    dft_shift = np.fft.fftshift(dft)
    
    phase_spectrum = np.angle(dft_shift)
    magnitude_spectrum = np.abs(dft_shift)
        
    return phase_spectrum, magnitude_spectrum

def compute_ifft(phase, magnitude):
    
    complex_spectrum = magnitude * np.exp(phase * 1j)
    shift = np.fft.ifftshift(complex_spectrum)
    ifft = np.fft.ifft2(shift)
    
    return np.abs(ifft)

# %% [markdown]
# Implement this function for changing phases and amplitudes of images.

# %%
def draw_phase_amplitude(image):
    '''
    Returns the phase image and the amplitude image from the input image.
    
    Parameters:
        image (numpy.ndarray): The input image.
    
    Returns:
        tuple of numpy.ndarray: The tuple of the phase image and the amplitude image.   
    '''
    
    phase, amp = compute_phase_magnitude(image)
    amp = np.log(amp)
    
    return phase, amp

def change_phase_domain(image1, image2):
    '''
    Substitutes the phase of image1 by the phase of image2 and returns two new images.
    
    Parameters:
        image1 (numpy.ndarray): The input image1.
        image2 (numpy.ndarray): The input image2.
    
    Returns:
        tuple of numpy.ndarray: The tuple of result images.   
    '''
    
    phase_1, mag_1 = compute_phase_magnitude(image1)
    phase_2, mag_2 = compute_phase_magnitude(image2)
    
    img1 = compute_ifft(phase_1, mag_2)
    img2 = compute_ifft(phase_2, mag_1)
    
    return img1, img2

# %% [markdown]
# Test your implementation (dont change this cell)

# %%
image_list = []
image1 = cv2.imread(os.path.join('images', '1.jpg'), cv2.IMREAD_GRAYSCALE)
image2 = cv2.imread(os.path.join('images', '2.jpg'), cv2.IMREAD_GRAYSCALE)

image_list.append([image1, 'source 1', 'img'])

phase1, amp1 = draw_phase_amplitude(image1)
image_list.append([phase1, 'phase source 1', 'img'])
image_list.append([amp1, 'amplitude source 1', 'img'])

image_list.append([image2, 'source 2', 'img'])

phase2, amp2 = draw_phase_amplitude(image2)
image_list.append([phase2, 'phase source 2', 'img'])
image_list.append([amp2, 'amplitude source 2', 'img'])

res1, res2 = change_phase_domain(image1, image2)
image_list.append([res1, 'new image 1', 'img'])
image_list.append([res2, 'new image 2', 'img'])

plotter(image_list, 4, 2, True, 10, 8, 'Q3')

# %% [markdown]
# # PART 4
#
# **Point : 25 pts**

# %% [markdown]
# Here is for your helper functions(optional)

# %% [markdown]
# Implement this function for denoising input image and return the result image.

# %%
def denoise_image(image):
    '''
    Denoises the input image.
    
    Parameters:
        image (numpy.ndarray): The input image.
    
    Returns:
        numpy.ndarray: The result denoised image.   
    '''
    
    denoised = image.copy()
    
    dft = np.fft.fft2(image)
    dft_shift = np.fft.fftshift(dft)
    
    dft_shift[:,:190] = 0.000001
    dft_shift[:,320:] = 0.000001

    dft_shift[:190,:] = 0.000001
    dft_shift[320:,:] = 0.000001
    
    idft_shift = np.fft.ifftshift(dft_shift)
    idft = np.fft.ifft2(idft_shift)
    
    denoised = np.abs(idft)
    return denoised

# %% [markdown]
# Test your implementation (dont change this cell)

# %%
image_list = []
image = cv2.imread(os.path.join('images', '3.jpg'), cv2.IMREAD_GRAYSCALE)
image_list.append([image, 'source', 'img'])
image_list.append([denoise_image(image), 'denoised', 'img'])
plotter(image_list, 1, 2, True, 8, 6, 'Q4')

# %% [markdown]
# # PART 5
#
# **Point : 25 pts**

# %% [markdown]
# Here is for your helper functions(optional)

# %%
def Hamming_2d(x, y, r):
        
    ham_x = np.hamming(x).reshape(x, 1)
    ham_y = np.hamming(y).reshape(1, y)

    ham2d = np.sqrt(np.dot(ham_x, ham_y)) ** r # expand to 2D hamming

    return ham2d

def Gaussian(x, y):
    sigma = 1
    gaussian_filter = np.zeros((x, y), np.float32)
    
    m = x//2
    n = y//2

    for x in range(-m, m+1):
        for y in range(-n, n+1):
            x1 = 2 * np.pi * (sigma ** 2)
            x2 = np.exp( -(x ** 2 + y ** 2)/(2 * sigma ** 2))
            gaussian_filter[x + m, y + n] = (1 / x1) * x2
    return gaussian_filter

def gaussian(x, y, std):
    return (1 / (2 * np.pi * np.square(std))) * (np.exp(-(np.square(x) + np.square(y)) / (2 * np.square(std))))

def gaussian_filter(x, y, std):
    '''
    Creates the Guassian kernel with given size and std.
    
    Parameters:
        size (int): The size of the kernel. It must be odd.
        std (float): The standard deviation of the kernel.
    
    Returns:
        numpy.ndarray: The Guassina kernel.
    '''
    
    kernel = np.zeros((x, y), np.float)
    
    ####### your code ########
    zero_based_gap_x = np.floor(x / 2)
    zero_based_gap_y = np.floor(y / 2)
    
    for i in range(kernel.shape[0]):
        for j in range(kernel.shape[1]):
            x = i - zero_based_gap_x
            y = j - zero_based_gap_y
            kernel[i, j] = gaussian(x, y, std)


    ##########################
    return kernel

# %% [markdown]
# Implement this function for enhancing input image and return result image.

# %%
def enhance_image(image):
    '''
    Enhances the input image by applying a filter in the frequency domain.
    
    Parameters:
        image (numpy.ndarray): The input image.
    
    Returns:
        numpy.ndarray: The result enhanced image.   
    '''
    
    filter_list = []
    gaussian_filter = gaussian_filter(image.shape[0], image.shape[1])
    
    filter_inv = 1 - gaussian_filter
#     ham = Hamming_2d(image.shape[0], image.shape[1], 1)  
#     filter_list.append([ham, 'ham','img'])
    
#     ham_inv = (1 - ham)
#     filter_list.append([ham_inv, 'ham inv','img'])
    
    
#     ham_center = Hamming_2d(image.shape[0], image.shape[1], 1000)
#     filter_list.append([ham_center, 'ham center','img'])

    
#     ham_final = ham_inv + ham_center + 1
#     ham_final = ham_inv
#     ham_final = ham_inv
#     filter_list.append([ham_final, 'ham final','img'])
    
    
    
#     plotter(filter_list, 2, 2, True, 8, 6, 'Filter')
    
    dft = np.fft.fft2(image)
    dft_shift = np.fft.fftshift(dft)
    
    dft_shift = dft_shift * filter_inv
    
#     dft_shift += edges 
    
    idft_shift = np.fft.ifftshift(dft_shift)
    idft = np.fft.ifft2(idft_shift)
    
    enhanced = np.abs(idft)
    return enhanced

# %% [markdown]
# Test your implementation (dont change this cell)

# %%
image_list = []
image = cv2.imread(os.path.join('images', '4.jpg'), cv2.IMREAD_GRAYSCALE)
image_list.append([image, 'source','img'])
image_list.append([enhance_image(image), 'enhanced', 'img'])
plotter(image_list, 1, 2, True, 8, 6, 'Q5')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-59004b595981> in <module>
#       2 image = cv2.imread(os.path.join('images', '4.jpg'), cv2.IMREAD_GRAYSCALE)
#       3 image_list.append([image, 'source','img'])
# ----> 4 image_list.append([enhance_image(image), 'enhanced', 'img'])
#       5 plotter(image_list, 1, 2, True, 8, 6, 'Q5')
#
# <ipython-input-21-403a783c924f> in enhance_image(image)
#      11
#      12     filter_list = []
# ---> 13     gaussian_filter = Gaussian(image.shape[0], image.shape[1])
#      14
#      15     filter_inv = 1 - gaussian_filter
#
# <ipython-input-20-b7f1e5973896> in Gaussian(x, y)
#      19             x1 = 2 * np.pi * (sigma ** 2)
#      20             x2 = np.exp( -(x ** 2 + y ** 2)/(2 * sigma ** 2))
# ---> 21             gaussian_filter[x + m, y + n] = (1 / x1) * x2
#      22     return gaussian_filter
#
# IndexError: index 1536 is out of bounds for axis 1 with size 1536

# %% [markdown]
# for create proper files for sending in quera run this cell.

# %%
# !python notebook_converter.py

# %% [markdown]
# End!!!

# %%
x = np.zeros((100, 100), dtype=np.uint8)

x[0::2,0::2] = 0
x[1::2,1::2] = 255


# x[0::8, :] = 0
# x[1::8, :] = 0

# x[2::8, :] = 0
# x[3::8, :] = 0

# x[5::8, :] = 255
# x[6::8, :] = 255
# x[7::8, :] = 255
# x[8::8, :] = 255

plt.gray()
plt.imshow(x)
plt.show()

# %%
dft = np.fft.fft2(x)
dft_shift = np.fft.fftshift(dft)
    
phase_spectrum = np.angle(dft_shift)
magnitude_spectrum = np.abs(dft_shift)

plt.imshow(magnitude_spectrum)
plt.show()
plt.imshow(phase_spectrum)
plt.show()

# %%
# a = np.random.randn(8 ,8) + 20
# print(np.mean(a))

b = np.array([1,1,1,1], dtype=np.uint8).reshape((2, 2))
# a = np.ones((8, 8)) * 20
a = np.array([0,1,1,0], dtype=np.uint8).reshape((2, 2))
print(a)
print(b)
# print(b)
# c = np.array([1,1], dtype=np.uint8).reshape((1, 2))
# print(a + b)
# Out:
# [[0 1]
#  [1 0]]
# [[1 1]
#  [1 1]]

# %%
dft_a = np.fft.fft2(a)
dft_a = np.fft.fft2(b)
# dft_a = np.fft.fftshift(dft_a)
print(dft_a)
print(dft_b)

print(dft_a + dft_b)
# dft_b = np.fft.fft2(b)
# print(dft_b)

# dft_sum = np.fft.fft2(a + b)
# print(dft_sum)

# print(dft_sum == dft_a + dft_b)

# dft_c = np.fft.fft2(c)
# print(dft_c)
# Out:
# [[4.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-1b6640af12eb> in <module>
#       3 # dft_a = np.fft.fftshift(dft_a)
#       4 print(dft_a)
# ----> 5 print(dft_b)
#       6
#       7 print(dft_a + dft_b)
#
# NameError: name 'dft_b' is not defined
